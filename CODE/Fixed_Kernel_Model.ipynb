# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dense, AveragePooling2D, Conv2DTranspose, Flatten, Reshape, Layer
from tensorflow.keras.models import Model, load_model
import numpy as np
import numpy.ma as ma
from netCDF4 import Dataset
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import datetime as dt
import cartopy.feature as cfeature
from sklearn.model_selection import train_test_split

# %%
#set the paths
data_path = '/Users/justinhudson/Documents/HW/ATS_780/Homework_2/DATA'
figure_path = '/Users/justinhudson/Documents/HW/ATS_780/Homework_2/FIGURES/'
root = '/Users/justinhudson/Documents/HW/ATS_780/Homework_2'

# %%
# set the seed
rand_seed = 144
np.random.seed(rand_seed)
tf.random.set_seed(rand_seed)

# %%
#bring in the data
os.chdir(data_path)
e5data = Dataset('ERA5_200hpa_U_V_relVort_Colorado_2021_2022.nc')
u = e5data.variables['u'][:]
v = e5data.variables['v'][:]
vort = e5data.variables['vo'][:]
lats = e5data.variables['latitude'][:]
lons = e5data.variables['longitude'][:]
time = e5data.variables['time'][:]
#convert times to usable dates
ref_date = dt.datetime(1900,1,1)
dates = np.array( [ ref_date + dt.timedelta(hours = int(t)) for t in time ] )

# %%
#let's limit the data
num_samples = 5000
time_start = np.random.randint(0,len(dates)-num_samples)
u = u[time_start:time_start+num_samples]
v = v[time_start:time_start+num_samples]
vort = vort[time_start:time_start+num_samples]
dates = dates[time_start:time_start+num_samples]

# %%
# normalize the data
def normalize_data(dataset:np.ndarray) -> np.ndarray:
    '''
        Normalizes data so that it is on the range 0-1 and then returns
        the normalized data.

        Inputs:
            dataset (np.ndarray): The dataset to be normalized
        
        Outputs:
            norm_data (np.ndarray): The normalized data
    '''

    data_min = np.nanmin(dataset)
    data_max = np.nanmax(dataset)

    norm_data = (dataset[:] - data_min) / (data_max - data_min)

    return norm_data, data_min, data_max

def denormalize_data(normed_data:np.ndarray,orig_min:float,orig_max:float) -> np.ndarray:
    '''
        De-normalizes a dataset using the min and max from the
        original dataset.

        Inputs:
            normed_data (np.ndarray): The dataset to be de-normalized, should
                have a range of [0-1]
            orig_min (float): The original minima of the dataset which was
                used to normalize it
            orig_max (float): The original maxima of the dataset which was
                used to normalize it
        
        Returns:
            denormed_data (np.ndarray): The denormalized dataset which should
                have a range of [orig_min,orig_max]
    '''

    denormed_data = (normed_data * (orig_max - orig_min)) + orig_min

    return denormed_data

u_norm,u_min,u_max = normalize_data(u)
v_norm,v_min,v_max = normalize_data(v)
vort_norm,vort_min,vort_max = normalize_data(vort)

# %%
# Combine u and v such that they are images with 2 "channels"
uv_data = np.empty((u.shape[0],u.shape[1],u.shape[2],2))
uv_data[:,:,:,0] = u_norm[:]
uv_data[:,:,:,1] = v_norm[:]
# uv_data is a 4D array of shape (time,lat,lon,channel)

# %%
# Split the data in testing/validation/training
# 10% will be testing
# 20% of the remainder will be validation
# the remainder of that will be training data


x_train,x_test,y_train,y_test = train_test_split(uv_data,vort_norm,test_size=0.1,
                                                 shuffle=True, random_state= rand_seed)
#now split off the validation from the training
x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size=0.2,
                                               shuffle = True,random_state= rand_seed)

# print the shapes to verify things look right
print("TRAINING, VALIDATION, AND TESTING SHAPES:")
print(f'XTRAIN: {x_train.shape}, XVAL: {x_val.shape}, XTEST: {x_test.shape}')
print(f'YTRAIN: {y_train.shape}, YVAL: {y_val.shape}, YTEST: {y_test.shape}')
# Out:
# TRAINING, VALIDATION, AND TESTING SHAPES:
# XTRAIN: (3600, 25, 41, 2), XVAL: (900, 25, 41, 2), XTEST: (500, 25, 41, 2)
# YTRAIN: (3600, 25, 41), YVAL: (900, 25, 41), YTEST: (500, 25, 41)

# %% [markdown]
# # Define the Fixed Kernel Model here
#
# #### The idea is to have a single convolutional layer, it will have fixed kernels to match Sobel DX, and Sobel DY and we'll see how it performs compared to the original model

# %%
# define the kernels I want to use
DX = np.array([[[0],[0],[0]],[[-2],[0],[2]],[[0],[0],[0]]])
DY = np.array([[[0],[2],[0]],[[0],[0],[0]],[[0],[-2],[0]]])

sobel_combined = np.zeros((3,3,2,2)) 
sobel_combined[:,:,0,1] = np.array([[0,1,0],[0,0,0],[0,-1,0]]) # U channel
sobel_combined[:,:,1,0] = np.array([[0,0,0],[-1,0,1],[0,0,0]]) # V channel
sobel_combined[:,:,0,0] = np.array([[0,-1,0],[0,0,0],[0,1,0]]) # U Channel
sobel_combined[:,:,1,1] = np.array([[0,0,0],[1,0,-1],[0,0,0]]) # V channel

# %%
def my_filter(shape, dtype=None):
    print(shape)

    assert sobel_combined.shape == shape
    return K.variable(sobel_combined, dtype='float32')

def compile_model() -> None:
    '''
        Constructs the CNN Model
    '''
    global model

    # Input Layers
    input_layer = Input(shape=x_train.shape[1:]) # (lat,lon, channels)

    layers = Layer()(input_layer)


    # Convolutional Layer with the set filters
    # the layer need to be set such that it is not trainable
    layers = Conv2D(2,KERNEL_SIZE, strides = STRIDE,
                        activation = CONV_ACTIVATION, kernel_initializer = my_filter,
                        trainable = False, padding = 'same')(layers)

    conv_shape = layers.shape

    # Transpose Convolutional Layers
    # for ilay in range(N_CONV_LAYERS):
    #     layers = Conv2DTranspose(N_FILTERS,KERNEL_SIZE,strides = STRIDE,
    #                              activation=CONV_ACTIVATION, padding='same')(layers)
    # layers = UpSampling2D(POOL_SIZE)(layers)
    output_layer = Conv2D(1, KERNEL_SIZE, activation='linear', padding='same', name = "Output_Layer")(layers)

    # Contruct the model
    model = Model(input_layer,output_layer)
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(optimizer=optimizer,loss = LOSS, metrics=[METRIC])

    model.summary()

def fit_model():
    global history

    history = model.fit(x_train,y_train, epochs = NUM_EPOCHS, verbose=VERBOSITY,
                        batch_size = BATCH_SIZE, shuffle=True, validation_data=[x_val,y_val],
                        callbacks=[early_stopping_callback])

def train_model():
    compile_model()
    fit_model()

# %%
# DEFINE MODEL HYPERPARAMETERS HERE

SEED = rand_seed #keep my randomseed the same throughout the notebook

LOSS = 'mse'
METRIC = 'mae'

NUM_EPOCHS = 10000
BATCH_SIZE = 32
VERBOSITY = 2
LEARNING_RATE = 5e-4

# CONVOLUTIONAL LAYER CHOICES
N_CONV_LAYERS = 1
N_FILTERS = 2
KERNEL_SIZE = (3,3)
STRIDE = (1,1)
CONV_ACTIVATION = 'relu'

# DEFINE EARLY STOPPING
PATIENCE = 25
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = "val_loss", patience=PATIENCE,restore_best_weights=True,
    mode="auto",verbose=1
)

# %%
tf.keras.backend.clear_session()
tf.keras.utils.set_random_seed(rand_seed)
train_model()
model.save(data_path + f'/MODELS/nontrainable_model')
# Out:
# (3, 3, 2, 2)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 25, 41, 2)]       0
#
#  layer (Layer)               (None, 25, 41, 2)         0
#
#  conv2d (Conv2D)             (None, 25, 41, 2)         38
#
#  Output_Layer (Conv2D)       (None, 25, 41, 1)         19
#
# =================================================================
# Total params: 57
# Trainable params: 19
# Non-trainable params: 38
# _________________________________________________________________
# Epoch 1/10000
# 2023-11-10 09:02:41.942213: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 113/113 - 1s - loss: 0.2251 - mae: 0.4509 - val_loss: 0.1913 - val_mae: 0.4152 - 797ms/epoch - 7ms/step
# Epoch 2/10000
# 113/113 - 0s - loss: 0.1615 - mae: 0.3810 - val_loss: 0.1374 - val_mae: 0.3515 - 469ms/epoch - 4ms/step
# Epoch 3/10000
# 113/113 - 0s - loss: 0.1159 - mae: 0.3222 - val_loss: 0.0988 - val_mae: 0.2970 - 456ms/epoch - 4ms/step
# Epoch 4/10000
# 113/113 - 0s - loss: 0.0832 - mae: 0.2715 - val_loss: 0.0710 - val_mae: 0.2498 - 434ms/epoch - 4ms/step
# Epoch 5/10000
# 113/113 - 0s - loss: 0.0598 - mae: 0.2280 - val_loss: 0.0512 - val_mae: 0.2099 - 349ms/epoch - 3ms/step
# Epoch 6/10000
# 113/113 - 0s - loss: 0.0432 - mae: 0.1917 - val_loss: 0.0372 - val_mae: 0.1771 - 340ms/epoch - 3ms/step
# Epoch 7/10000
# 113/113 - 0s - loss: 0.0316 - mae: 0.1624 - val_loss: 0.0275 - val_mae: 0.1508 - 338ms/epoch - 3ms/step
# Epoch 8/10000
# 113/113 - 0s - loss: 0.0235 - mae: 0.1388 - val_loss: 0.0207 - val_mae: 0.1294 - 339ms/epoch - 3ms/step
# Epoch 9/10000
# 113/113 - 0s - loss: 0.0179 - mae: 0.1196 - val_loss: 0.0159 - val_mae: 0.1119 - 337ms/epoch - 3ms/step
# Epoch 10/10000
# 113/113 - 0s - loss: 0.0138 - mae: 0.1037 - val_loss: 0.0124 - val_mae: 0.0974 - 342ms/epoch - 3ms/step
# Epoch 11/10000
# 113/113 - 0s - loss: 0.0109 - mae: 0.0905 - val_loss: 0.0099 - val_mae: 0.0855 - 338ms/epoch - 3ms/step
# Epoch 12/10000
# 113/113 - 0s - loss: 0.0087 - mae: 0.0798 - val_loss: 0.0080 - val_mae: 0.0757 - 338ms/epoch - 3ms/step
# Epoch 13/10000
# 113/113 - 0s - loss: 0.0071 - mae: 0.0709 - val_loss: 0.0066 - val_mae: 0.0677 - 339ms/epoch - 3ms/step
# Epoch 14/10000
# 113/113 - 0s - loss: 0.0059 - mae: 0.0636 - val_loss: 0.0055 - val_mae: 0.0611 - 339ms/epoch - 3ms/step
# Epoch 15/10000
# 113/113 - 0s - loss: 0.0049 - mae: 0.0577 - val_loss: 0.0046 - val_mae: 0.0559 - 336ms/epoch - 3ms/step
# Epoch 16/10000
# 113/113 - 0s - loss: 0.0042 - mae: 0.0530 - val_loss: 0.0040 - val_mae: 0.0517 - 341ms/epoch - 3ms/step
# Epoch 17/10000
# 113/113 - 0s - loss: 0.0037 - mae: 0.0493 - val_loss: 0.0036 - val_mae: 0.0483 - 338ms/epoch - 3ms/step
# Epoch 18/10000
# 113/113 - 0s - loss: 0.0033 - mae: 0.0463 - val_loss: 0.0032 - val_mae: 0.0457 - 336ms/epoch - 3ms/step
# Epoch 19/10000
# 113/113 - 0s - loss: 0.0030 - mae: 0.0440 - val_loss: 0.0029 - val_mae: 0.0436 - 336ms/epoch - 3ms/step
# Epoch 20/10000
# 113/113 - 0s - loss: 0.0028 - mae: 0.0421 - val_loss: 0.0027 - val_mae: 0.0420 - 339ms/epoch - 3ms/step
# Epoch 21/10000
# 113/113 - 0s - loss: 0.0026 - mae: 0.0406 - val_loss: 0.0026 - val_mae: 0.0406 - 338ms/epoch - 3ms/step
# Epoch 22/10000
# 113/113 - 0s - loss: 0.0025 - mae: 0.0394 - val_loss: 0.0025 - val_mae: 0.0395 - 338ms/epoch - 3ms/step
# Epoch 23/10000
# 113/113 - 0s - loss: 0.0023 - mae: 0.0384 - val_loss: 0.0024 - val_mae: 0.0385 - 337ms/epoch - 3ms/step
# Epoch 24/10000
# 113/113 - 0s - loss: 0.0022 - mae: 0.0375 - val_loss: 0.0023 - val_mae: 0.0376 - 338ms/epoch - 3ms/step
# Epoch 25/10000
# 113/113 - 0s - loss: 0.0022 - mae: 0.0366 - val_loss: 0.0022 - val_mae: 0.0368 - 336ms/epoch - 3ms/step
# Epoch 26/10000
# 113/113 - 0s - loss: 0.0021 - mae: 0.0359 - val_loss: 0.0021 - val_mae: 0.0360 - 338ms/epoch - 3ms/step
# Epoch 27/10000
# 113/113 - 0s - loss: 0.0020 - mae: 0.0352 - val_loss: 0.0020 - val_mae: 0.0353 - 336ms/epoch - 3ms/step
# Epoch 28/10000
# 113/113 - 0s - loss: 0.0020 - mae: 0.0345 - val_loss: 0.0020 - val_mae: 0.0346 - 347ms/epoch - 3ms/step
# Epoch 29/10000
# 113/113 - 0s - loss: 0.0019 - mae: 0.0338 - val_loss: 0.0019 - val_mae: 0.0339 - 337ms/epoch - 3ms/step
# Epoch 30/10000
# 113/113 - 0s - loss: 0.0018 - mae: 0.0331 - val_loss: 0.0018 - val_mae: 0.0332 - 336ms/epoch - 3ms/step
# Epoch 31/10000
# 113/113 - 0s - loss: 0.0018 - mae: 0.0325 - val_loss: 0.0018 - val_mae: 0.0325 - 336ms/epoch - 3ms/step
# Epoch 32/10000
# 113/113 - 0s - loss: 0.0017 - mae: 0.0318 - val_loss: 0.0017 - val_mae: 0.0318 - 337ms/epoch - 3ms/step
# Epoch 33/10000
# 113/113 - 0s - loss: 0.0017 - mae: 0.0311 - val_loss: 0.0017 - val_mae: 0.0312 - 337ms/epoch - 3ms/step
# Epoch 34/10000
# 113/113 - 0s - loss: 0.0016 - mae: 0.0305 - val_loss: 0.0016 - val_mae: 0.0305 - 338ms/epoch - 3ms/step
# Epoch 35/10000
# 113/113 - 0s - loss: 0.0016 - mae: 0.0298 - val_loss: 0.0016 - val_mae: 0.0299 - 338ms/epoch - 3ms/step
# Epoch 36/10000
# 113/113 - 0s - loss: 0.0015 - mae: 0.0292 - val_loss: 0.0015 - val_mae: 0.0292 - 337ms/epoch - 3ms/step
# Epoch 37/10000
# 113/113 - 0s - loss: 0.0015 - mae: 0.0286 - val_loss: 0.0015 - val_mae: 0.0286 - 337ms/epoch - 3ms/step
# Epoch 38/10000
# 113/113 - 0s - loss: 0.0014 - mae: 0.0280 - val_loss: 0.0014 - val_mae: 0.0279 - 342ms/epoch - 3ms/step
# Epoch 39/10000
# 113/113 - 0s - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0014 - val_mae: 0.0273 - 338ms/epoch - 3ms/step
# Epoch 40/10000
# 113/113 - 0s - loss: 0.0013 - mae: 0.0268 - val_loss: 0.0013 - val_mae: 0.0267 - 337ms/epoch - 3ms/step
# Epoch 41/10000
# 113/113 - 0s - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0013 - val_mae: 0.0262 - 356ms/epoch - 3ms/step
# Epoch 42/10000
# 113/113 - 0s - loss: 0.0012 - mae: 0.0256 - val_loss: 0.0012 - val_mae: 0.0256 - 338ms/epoch - 3ms/step
# Epoch 43/10000
# 113/113 - 0s - loss: 0.0012 - mae: 0.0251 - val_loss: 0.0012 - val_mae: 0.0250 - 335ms/epoch - 3ms/step
# Epoch 44/10000
# 113/113 - 0s - loss: 0.0012 - mae: 0.0245 - val_loss: 0.0012 - val_mae: 0.0245 - 337ms/epoch - 3ms/step
# Epoch 45/10000
# 113/113 - 0s - loss: 0.0011 - mae: 0.0241 - val_loss: 0.0011 - val_mae: 0.0239 - 335ms/epoch - 3ms/step
# Epoch 46/10000
# 113/113 - 0s - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0011 - val_mae: 0.0235 - 337ms/epoch - 3ms/step
# Epoch 47/10000
# 113/113 - 0s - loss: 0.0011 - mae: 0.0231 - val_loss: 0.0011 - val_mae: 0.0230 - 337ms/epoch - 3ms/step
# Epoch 48/10000
# 113/113 - 0s - loss: 0.0011 - mae: 0.0226 - val_loss: 0.0011 - val_mae: 0.0225 - 336ms/epoch - 3ms/step
# Epoch 49/10000
# 113/113 - 0s - loss: 0.0010 - mae: 0.0222 - val_loss: 0.0010 - val_mae: 0.0221 - 337ms/epoch - 3ms/step
# Epoch 50/10000
# 113/113 - 0s - loss: 0.0010 - mae: 0.0218 - val_loss: 0.0010 - val_mae: 0.0217 - 337ms/epoch - 3ms/step
# Epoch 51/10000
# 113/113 - 0s - loss: 9.8369e-04 - mae: 0.0214 - val_loss: 9.8611e-04 - val_mae: 0.0214 - 338ms/epoch - 3ms/step
# Epoch 52/10000
# 113/113 - 0s - loss: 9.6322e-04 - mae: 0.0211 - val_loss: 9.6678e-04 - val_mae: 0.0209 - 337ms/epoch - 3ms/step
# Epoch 53/10000
# 113/113 - 0s - loss: 9.4466e-04 - mae: 0.0207 - val_loss: 9.4673e-04 - val_mae: 0.0206 - 335ms/epoch - 3ms/step
# Epoch 54/10000
# 113/113 - 0s - loss: 9.2694e-04 - mae: 0.0204 - val_loss: 9.2935e-04 - val_mae: 0.0203 - 337ms/epoch - 3ms/step
# Epoch 55/10000
# 113/113 - 0s - loss: 9.1076e-04 - mae: 0.0201 - val_loss: 9.1303e-04 - val_mae: 0.0201 - 334ms/epoch - 3ms/step
# Epoch 56/10000
# 113/113 - 0s - loss: 8.9582e-04 - mae: 0.0199 - val_loss: 8.9908e-04 - val_mae: 0.0197 - 335ms/epoch - 3ms/step
# Epoch 57/10000
# 113/113 - 0s - loss: 8.8223e-04 - mae: 0.0196 - val_loss: 8.8417e-04 - val_mae: 0.0196 - 337ms/epoch - 3ms/step
# Epoch 58/10000
# 113/113 - 0s - loss: 8.6946e-04 - mae: 0.0194 - val_loss: 8.7136e-04 - val_mae: 0.0194 - 341ms/epoch - 3ms/step
# Epoch 59/10000
# 113/113 - 0s - loss: 8.5769e-04 - mae: 0.0192 - val_loss: 8.6056e-04 - val_mae: 0.0191 - 335ms/epoch - 3ms/step
# Epoch 60/10000
# 113/113 - 0s - loss: 8.4698e-04 - mae: 0.0191 - val_loss: 8.4889e-04 - val_mae: 0.0190 - 349ms/epoch - 3ms/step
# Epoch 61/10000
# 113/113 - 0s - loss: 8.3682e-04 - mae: 0.0189 - val_loss: 8.3894e-04 - val_mae: 0.0188 - 338ms/epoch - 3ms/step
# Epoch 62/10000
# 113/113 - 0s - loss: 8.2801e-04 - mae: 0.0188 - val_loss: 8.2999e-04 - val_mae: 0.0187 - 336ms/epoch - 3ms/step
# Epoch 63/10000
# 113/113 - 0s - loss: 8.1941e-04 - mae: 0.0187 - val_loss: 8.2114e-04 - val_mae: 0.0186 - 337ms/epoch - 3ms/step
# Epoch 64/10000
# 113/113 - 0s - loss: 8.1153e-04 - mae: 0.0185 - val_loss: 8.1372e-04 - val_mae: 0.0184 - 336ms/epoch - 3ms/step
# Epoch 65/10000
# 113/113 - 0s - loss: 8.0434e-04 - mae: 0.0185 - val_loss: 8.0578e-04 - val_mae: 0.0183 - 335ms/epoch - 3ms/step
# Epoch 66/10000
# 113/113 - 0s - loss: 7.9746e-04 - mae: 0.0183 - val_loss: 7.9880e-04 - val_mae: 0.0183 - 339ms/epoch - 3ms/step
# Epoch 67/10000
# 113/113 - 0s - loss: 7.9106e-04 - mae: 0.0183 - val_loss: 7.9221e-04 - val_mae: 0.0182 - 337ms/epoch - 3ms/step
# Epoch 68/10000
# 113/113 - 0s - loss: 7.8521e-04 - mae: 0.0182 - val_loss: 7.8635e-04 - val_mae: 0.0181 - 336ms/epoch - 3ms/step
# Epoch 69/10000
# 113/113 - 0s - loss: 7.7953e-04 - mae: 0.0182 - val_loss: 7.8073e-04 - val_mae: 0.0181 - 337ms/epoch - 3ms/step
# Epoch 70/10000
# 113/113 - 0s - loss: 7.7445e-04 - mae: 0.0181 - val_loss: 7.7540e-04 - val_mae: 0.0181 - 337ms/epoch - 3ms/step
# Epoch 71/10000
# 113/113 - 0s - loss: 7.6974e-04 - mae: 0.0181 - val_loss: 7.7019e-04 - val_mae: 0.0180 - 336ms/epoch - 3ms/step
# Epoch 72/10000
# 113/113 - 0s - loss: 7.6475e-04 - mae: 0.0180 - val_loss: 7.6543e-04 - val_mae: 0.0180 - 338ms/epoch - 3ms/step
# Epoch 73/10000
# 113/113 - 0s - loss: 7.6037e-04 - mae: 0.0180 - val_loss: 7.6096e-04 - val_mae: 0.0179 - 338ms/epoch - 3ms/step
# Epoch 74/10000
# 113/113 - 0s - loss: 7.5635e-04 - mae: 0.0180 - val_loss: 7.5715e-04 - val_mae: 0.0179 - 336ms/epoch - 3ms/step
# Epoch 75/10000
# 113/113 - 0s - loss: 7.5231e-04 - mae: 0.0179 - val_loss: 7.5347e-04 - val_mae: 0.0178 - 337ms/epoch - 3ms/step
# Epoch 76/10000
# 113/113 - 0s - loss: 7.4846e-04 - mae: 0.0179 - val_loss: 7.4878e-04 - val_mae: 0.0178 - 337ms/epoch - 3ms/step
# Epoch 77/10000
# 113/113 - 0s - loss: 7.4475e-04 - mae: 0.0179 - val_loss: 7.4517e-04 - val_mae: 0.0178 - 335ms/epoch - 3ms/step
# Epoch 78/10000
# 113/113 - 0s - loss: 7.4131e-04 - mae: 0.0178 - val_loss: 7.4125e-04 - val_mae: 0.0178 - 340ms/epoch - 3ms/step
# Epoch 79/10000
# 113/113 - 0s - loss: 7.3785e-04 - mae: 0.0178 - val_loss: 7.3788e-04 - val_mae: 0.0178 - 337ms/epoch - 3ms/step
# Epoch 80/10000
# 113/113 - 0s - loss: 7.3489e-04 - mae: 0.0178 - val_loss: 7.3535e-04 - val_mae: 0.0177 - 336ms/epoch - 3ms/step
# Epoch 81/10000
# 113/113 - 0s - loss: 7.3192e-04 - mae: 0.0178 - val_loss: 7.3149e-04 - val_mae: 0.0177 - 336ms/epoch - 3ms/step
# Epoch 82/10000
# 113/113 - 0s - loss: 7.2907e-04 - mae: 0.0178 - val_loss: 7.3065e-04 - val_mae: 0.0176 - 336ms/epoch - 3ms/step
# Epoch 83/10000
# 113/113 - 0s - loss: 7.2606e-04 - mae: 0.0178 - val_loss: 7.2699e-04 - val_mae: 0.0177 - 343ms/epoch - 3ms/step
# Epoch 84/10000
# 113/113 - 0s - loss: 7.2368e-04 - mae: 0.0178 - val_loss: 7.2415e-04 - val_mae: 0.0176 - 336ms/epoch - 3ms/step
# Epoch 85/10000
# 113/113 - 0s - loss: 7.2106e-04 - mae: 0.0177 - val_loss: 7.2103e-04 - val_mae: 0.0176 - 336ms/epoch - 3ms/step
# Epoch 86/10000
# 113/113 - 0s - loss: 7.1860e-04 - mae: 0.0177 - val_loss: 7.1858e-04 - val_mae: 0.0176 - 337ms/epoch - 3ms/step
# Epoch 87/10000
# 113/113 - 0s - loss: 7.1652e-04 - mae: 0.0177 - val_loss: 7.1563e-04 - val_mae: 0.0176 - 336ms/epoch - 3ms/step
# Epoch 88/10000
# 113/113 - 0s - loss: 7.1414e-04 - mae: 0.0177 - val_loss: 7.1363e-04 - val_mae: 0.0176 - 337ms/epoch - 3ms/step
# Epoch 89/10000
# 113/113 - 0s - loss: 7.1224e-04 - mae: 0.0177 - val_loss: 7.1156e-04 - val_mae: 0.0177 - 336ms/epoch - 3ms/step
# Epoch 90/10000
# 113/113 - 0s - loss: 7.1023e-04 - mae: 0.0177 - val_loss: 7.0937e-04 - val_mae: 0.0176 - 334ms/epoch - 3ms/step
# Epoch 91/10000
# 113/113 - 0s - loss: 7.0850e-04 - mae: 0.0176 - val_loss: 7.0840e-04 - val_mae: 0.0176 - 337ms/epoch - 3ms/step
# Epoch 92/10000
# 113/113 - 0s - loss: 7.0680e-04 - mae: 0.0176 - val_loss: 7.0604e-04 - val_mae: 0.0176 - 336ms/epoch - 3ms/step
# Epoch 93/10000
# 113/113 - 0s - loss: 7.0532e-04 - mae: 0.0176 - val_loss: 7.0454e-04 - val_mae: 0.0176 - 334ms/epoch - 3ms/step
# Epoch 94/10000
# 113/113 - 0s - loss: 7.0373e-04 - mae: 0.0176 - val_loss: 7.0261e-04 - val_mae: 0.0175 - 337ms/epoch - 3ms/step
# Epoch 95/10000
# 113/113 - 0s - loss: 7.0266e-04 - mae: 0.0176 - val_loss: 7.0113e-04 - val_mae: 0.0176 - 340ms/epoch - 3ms/step
# Epoch 96/10000
# 113/113 - 0s - loss: 7.0103e-04 - mae: 0.0176 - val_loss: 7.0026e-04 - val_mae: 0.0175 - 336ms/epoch - 3ms/step
# Epoch 97/10000
# 113/113 - 0s - loss: 6.9954e-04 - mae: 0.0176 - val_loss: 6.9875e-04 - val_mae: 0.0176 - 338ms/epoch - 3ms/step
# Epoch 98/10000
# 113/113 - 0s - loss: 6.9835e-04 - mae: 0.0176 - val_loss: 6.9737e-04 - val_mae: 0.0175 - 338ms/epoch - 3ms/step
# Epoch 99/10000
# 113/113 - 0s - loss: 6.9711e-04 - mae: 0.0176 - val_loss: 6.9684e-04 - val_mae: 0.0174 - 335ms/epoch - 3ms/step
# Epoch 100/10000
# 113/113 - 0s - loss: 6.9592e-04 - mae: 0.0176 - val_loss: 6.9643e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 101/10000
# 113/113 - 0s - loss: 6.9503e-04 - mae: 0.0176 - val_loss: 6.9400e-04 - val_mae: 0.0175 - 338ms/epoch - 3ms/step
# Epoch 102/10000
# 113/113 - 0s - loss: 6.9416e-04 - mae: 0.0176 - val_loss: 6.9391e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 103/10000
# 113/113 - 0s - loss: 6.9325e-04 - mae: 0.0176 - val_loss: 6.9220e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 104/10000
# 113/113 - 0s - loss: 6.9243e-04 - mae: 0.0175 - val_loss: 6.9160e-04 - val_mae: 0.0175 - 337ms/epoch - 3ms/step
# Epoch 105/10000
# 113/113 - 0s - loss: 6.9160e-04 - mae: 0.0175 - val_loss: 6.9033e-04 - val_mae: 0.0175 - 337ms/epoch - 3ms/step
# Epoch 106/10000
# 113/113 - 0s - loss: 6.9079e-04 - mae: 0.0175 - val_loss: 6.9036e-04 - val_mae: 0.0174 - 338ms/epoch - 3ms/step
# Epoch 107/10000
# 113/113 - 0s - loss: 6.9036e-04 - mae: 0.0175 - val_loss: 6.8929e-04 - val_mae: 0.0175 - 337ms/epoch - 3ms/step
# Epoch 108/10000
# 113/113 - 0s - loss: 6.8952e-04 - mae: 0.0175 - val_loss: 6.8816e-04 - val_mae: 0.0174 - 334ms/epoch - 3ms/step
# Epoch 109/10000
# 113/113 - 0s - loss: 6.8880e-04 - mae: 0.0175 - val_loss: 6.8815e-04 - val_mae: 0.0175 - 335ms/epoch - 3ms/step
# Epoch 110/10000
# 113/113 - 0s - loss: 6.8843e-04 - mae: 0.0175 - val_loss: 6.8711e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 111/10000
# 113/113 - 0s - loss: 6.8778e-04 - mae: 0.0175 - val_loss: 6.8718e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 112/10000
# 113/113 - 0s - loss: 6.8720e-04 - mae: 0.0175 - val_loss: 6.8639e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 113/10000
# 113/113 - 0s - loss: 6.8731e-04 - mae: 0.0175 - val_loss: 6.8644e-04 - val_mae: 0.0175 - 337ms/epoch - 3ms/step
# Epoch 114/10000
# 113/113 - 0s - loss: 6.8637e-04 - mae: 0.0175 - val_loss: 6.8555e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 115/10000
# 113/113 - 0s - loss: 6.8615e-04 - mae: 0.0175 - val_loss: 6.8464e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 116/10000
# 113/113 - 0s - loss: 6.8561e-04 - mae: 0.0175 - val_loss: 6.8519e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 117/10000
# 113/113 - 0s - loss: 6.8561e-04 - mae: 0.0175 - val_loss: 6.8423e-04 - val_mae: 0.0174 - 333ms/epoch - 3ms/step
# Epoch 118/10000
# 113/113 - 0s - loss: 6.8539e-04 - mae: 0.0175 - val_loss: 6.8417e-04 - val_mae: 0.0175 - 374ms/epoch - 3ms/step
# Epoch 119/10000
# 113/113 - 0s - loss: 6.8478e-04 - mae: 0.0175 - val_loss: 6.8474e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 120/10000
# 113/113 - 0s - loss: 6.8455e-04 - mae: 0.0175 - val_loss: 6.8293e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 121/10000
# 113/113 - 0s - loss: 6.8402e-04 - mae: 0.0175 - val_loss: 6.8393e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 122/10000
# 113/113 - 0s - loss: 6.8449e-04 - mae: 0.0175 - val_loss: 6.8376e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 123/10000
# 113/113 - 0s - loss: 6.8352e-04 - mae: 0.0175 - val_loss: 6.8471e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 124/10000
# 113/113 - 0s - loss: 6.8390e-04 - mae: 0.0175 - val_loss: 6.8318e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 125/10000
# 113/113 - 0s - loss: 6.8334e-04 - mae: 0.0175 - val_loss: 6.8201e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 126/10000
# 113/113 - 0s - loss: 6.8285e-04 - mae: 0.0175 - val_loss: 6.8218e-04 - val_mae: 0.0174 - 450ms/epoch - 4ms/step
# Epoch 127/10000
# 113/113 - 0s - loss: 6.8287e-04 - mae: 0.0175 - val_loss: 6.8187e-04 - val_mae: 0.0174 - 410ms/epoch - 4ms/step
# Epoch 128/10000
# 113/113 - 0s - loss: 6.8303e-04 - mae: 0.0175 - val_loss: 6.8155e-04 - val_mae: 0.0174 - 355ms/epoch - 3ms/step
# Epoch 129/10000
# 113/113 - 0s - loss: 6.8222e-04 - mae: 0.0175 - val_loss: 6.8137e-04 - val_mae: 0.0174 - 408ms/epoch - 4ms/step
# Epoch 130/10000
# 113/113 - 0s - loss: 6.8259e-04 - mae: 0.0175 - val_loss: 6.8136e-04 - val_mae: 0.0174 - 430ms/epoch - 4ms/step
# Epoch 131/10000
# 113/113 - 0s - loss: 6.8244e-04 - mae: 0.0175 - val_loss: 6.8148e-04 - val_mae: 0.0174 - 340ms/epoch - 3ms/step
# Epoch 132/10000
# 113/113 - 0s - loss: 6.8218e-04 - mae: 0.0175 - val_loss: 6.8311e-04 - val_mae: 0.0174 - 457ms/epoch - 4ms/step
# Epoch 133/10000
# 113/113 - 0s - loss: 6.8202e-04 - mae: 0.0175 - val_loss: 6.8143e-04 - val_mae: 0.0174 - 471ms/epoch - 4ms/step
# Epoch 134/10000
# 113/113 - 0s - loss: 6.8203e-04 - mae: 0.0175 - val_loss: 6.8182e-04 - val_mae: 0.0175 - 405ms/epoch - 4ms/step
# Epoch 135/10000
# 113/113 - 0s - loss: 6.8223e-04 - mae: 0.0175 - val_loss: 6.8039e-04 - val_mae: 0.0174 - 335ms/epoch - 3ms/step
# Epoch 136/10000
# 113/113 - 0s - loss: 6.8221e-04 - mae: 0.0175 - val_loss: 6.8094e-04 - val_mae: 0.0174 - 340ms/epoch - 3ms/step
# Epoch 137/10000
# 113/113 - 0s - loss: 6.8186e-04 - mae: 0.0175 - val_loss: 6.8059e-04 - val_mae: 0.0174 - 353ms/epoch - 3ms/step
# Epoch 138/10000
# 113/113 - 1s - loss: 6.8197e-04 - mae: 0.0175 - val_loss: 6.8055e-04 - val_mae: 0.0173 - 505ms/epoch - 4ms/step
# Epoch 139/10000
# 113/113 - 0s - loss: 6.8145e-04 - mae: 0.0175 - val_loss: 6.8231e-04 - val_mae: 0.0173 - 375ms/epoch - 3ms/step
# Epoch 140/10000
# 113/113 - 0s - loss: 6.8140e-04 - mae: 0.0175 - val_loss: 6.8001e-04 - val_mae: 0.0174 - 342ms/epoch - 3ms/step
# Epoch 141/10000
# 113/113 - 0s - loss: 6.8120e-04 - mae: 0.0175 - val_loss: 6.8058e-04 - val_mae: 0.0174 - 341ms/epoch - 3ms/step
# Epoch 142/10000
# 113/113 - 0s - loss: 6.8099e-04 - mae: 0.0175 - val_loss: 6.8049e-04 - val_mae: 0.0174 - 436ms/epoch - 4ms/step
# Epoch 143/10000
# 113/113 - 0s - loss: 6.8101e-04 - mae: 0.0175 - val_loss: 6.8056e-04 - val_mae: 0.0174 - 365ms/epoch - 3ms/step
# Epoch 144/10000
# 113/113 - 0s - loss: 6.8098e-04 - mae: 0.0175 - val_loss: 6.7960e-04 - val_mae: 0.0174 - 479ms/epoch - 4ms/step
# Epoch 145/10000
# 113/113 - 0s - loss: 6.8093e-04 - mae: 0.0175 - val_loss: 6.7944e-04 - val_mae: 0.0174 - 463ms/epoch - 4ms/step
# Epoch 146/10000
# 113/113 - 0s - loss: 6.8106e-04 - mae: 0.0175 - val_loss: 6.7994e-04 - val_mae: 0.0174 - 445ms/epoch - 4ms/step
# Epoch 147/10000
# 113/113 - 0s - loss: 6.8122e-04 - mae: 0.0175 - val_loss: 6.8058e-04 - val_mae: 0.0175 - 498ms/epoch - 4ms/step
# Epoch 148/10000
# 113/113 - 0s - loss: 6.8131e-04 - mae: 0.0175 - val_loss: 6.8154e-04 - val_mae: 0.0174 - 458ms/epoch - 4ms/step
# Epoch 149/10000
# 113/113 - 0s - loss: 6.8136e-04 - mae: 0.0175 - val_loss: 6.7950e-04 - val_mae: 0.0174 - 425ms/epoch - 4ms/step
# Epoch 150/10000
# 113/113 - 0s - loss: 6.8089e-04 - mae: 0.0175 - val_loss: 6.7986e-04 - val_mae: 0.0174 - 427ms/epoch - 4ms/step
# Epoch 151/10000
# 113/113 - 0s - loss: 6.8050e-04 - mae: 0.0175 - val_loss: 6.8044e-04 - val_mae: 0.0173 - 342ms/epoch - 3ms/step
# Epoch 152/10000
# 113/113 - 0s - loss: 6.8057e-04 - mae: 0.0175 - val_loss: 6.8015e-04 - val_mae: 0.0173 - 344ms/epoch - 3ms/step
# Epoch 153/10000
# 113/113 - 0s - loss: 6.8062e-04 - mae: 0.0175 - val_loss: 6.7926e-04 - val_mae: 0.0174 - 341ms/epoch - 3ms/step
# Epoch 154/10000
# 113/113 - 0s - loss: 6.8091e-04 - mae: 0.0175 - val_loss: 6.8050e-04 - val_mae: 0.0174 - 339ms/epoch - 3ms/step
# Epoch 155/10000
# 113/113 - 0s - loss: 6.8047e-04 - mae: 0.0175 - val_loss: 6.7914e-04 - val_mae: 0.0173 - 337ms/epoch - 3ms/step
# Epoch 156/10000
# 113/113 - 0s - loss: 6.8040e-04 - mae: 0.0175 - val_loss: 6.7991e-04 - val_mae: 0.0174 - 344ms/epoch - 3ms/step
# Epoch 157/10000
# 113/113 - 0s - loss: 6.8069e-04 - mae: 0.0175 - val_loss: 6.7917e-04 - val_mae: 0.0174 - 335ms/epoch - 3ms/step
# Epoch 158/10000
# 113/113 - 0s - loss: 6.8051e-04 - mae: 0.0175 - val_loss: 6.7936e-04 - val_mae: 0.0173 - 337ms/epoch - 3ms/step
# Epoch 159/10000
# 113/113 - 0s - loss: 6.8043e-04 - mae: 0.0174 - val_loss: 6.7879e-04 - val_mae: 0.0174 - 334ms/epoch - 3ms/step
# Epoch 160/10000
# 113/113 - 0s - loss: 6.8040e-04 - mae: 0.0175 - val_loss: 6.7909e-04 - val_mae: 0.0174 - 334ms/epoch - 3ms/step
# Epoch 161/10000
# 113/113 - 0s - loss: 6.8053e-04 - mae: 0.0174 - val_loss: 6.7922e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 162/10000
# 113/113 - 0s - loss: 6.8081e-04 - mae: 0.0175 - val_loss: 6.7979e-04 - val_mae: 0.0174 - 341ms/epoch - 3ms/step
# Epoch 163/10000
# 113/113 - 0s - loss: 6.8046e-04 - mae: 0.0175 - val_loss: 6.7965e-04 - val_mae: 0.0173 - 340ms/epoch - 3ms/step
# Epoch 164/10000
# 113/113 - 0s - loss: 6.8083e-04 - mae: 0.0175 - val_loss: 6.7902e-04 - val_mae: 0.0174 - 342ms/epoch - 3ms/step
# Epoch 165/10000
# 113/113 - 0s - loss: 6.8065e-04 - mae: 0.0175 - val_loss: 6.8010e-04 - val_mae: 0.0174 - 342ms/epoch - 3ms/step
# Epoch 166/10000
# 113/113 - 0s - loss: 6.8018e-04 - mae: 0.0175 - val_loss: 6.7885e-04 - val_mae: 0.0174 - 391ms/epoch - 3ms/step
# Epoch 167/10000
# 113/113 - 0s - loss: 6.8031e-04 - mae: 0.0175 - val_loss: 6.7896e-04 - val_mae: 0.0174 - 454ms/epoch - 4ms/step
# Epoch 168/10000
# 113/113 - 0s - loss: 6.8032e-04 - mae: 0.0174 - val_loss: 6.7904e-04 - val_mae: 0.0174 - 424ms/epoch - 4ms/step
# Epoch 169/10000
# 113/113 - 0s - loss: 6.8028e-04 - mae: 0.0175 - val_loss: 6.7920e-04 - val_mae: 0.0174 - 397ms/epoch - 4ms/step
# Epoch 170/10000
# 113/113 - 0s - loss: 6.8066e-04 - mae: 0.0175 - val_loss: 6.7927e-04 - val_mae: 0.0174 - 347ms/epoch - 3ms/step
# Epoch 171/10000
# 113/113 - 0s - loss: 6.8067e-04 - mae: 0.0175 - val_loss: 6.7964e-04 - val_mae: 0.0174 - 341ms/epoch - 3ms/step
# Epoch 172/10000
# 113/113 - 0s - loss: 6.8025e-04 - mae: 0.0174 - val_loss: 6.7877e-04 - val_mae: 0.0174 - 341ms/epoch - 3ms/step
# Epoch 173/10000
# 113/113 - 0s - loss: 6.8039e-04 - mae: 0.0175 - val_loss: 6.7867e-04 - val_mae: 0.0174 - 342ms/epoch - 3ms/step
# Epoch 174/10000
# 113/113 - 0s - loss: 6.8073e-04 - mae: 0.0175 - val_loss: 6.7855e-04 - val_mae: 0.0174 - 441ms/epoch - 4ms/step
# Epoch 175/10000
# 113/113 - 0s - loss: 6.7998e-04 - mae: 0.0175 - val_loss: 6.8013e-04 - val_mae: 0.0174 - 384ms/epoch - 3ms/step
# Epoch 176/10000
# 113/113 - 1s - loss: 6.8023e-04 - mae: 0.0174 - val_loss: 6.7987e-04 - val_mae: 0.0173 - 509ms/epoch - 5ms/step
# Epoch 177/10000
# 113/113 - 0s - loss: 6.8020e-04 - mae: 0.0174 - val_loss: 6.7945e-04 - val_mae: 0.0173 - 416ms/epoch - 4ms/step
# Epoch 178/10000
# 113/113 - 0s - loss: 6.8054e-04 - mae: 0.0175 - val_loss: 6.8062e-04 - val_mae: 0.0173 - 463ms/epoch - 4ms/step
# Epoch 179/10000
# 113/113 - 0s - loss: 6.8009e-04 - mae: 0.0175 - val_loss: 6.8159e-04 - val_mae: 0.0175 - 490ms/epoch - 4ms/step
# Epoch 180/10000
# 113/113 - 0s - loss: 6.8056e-04 - mae: 0.0175 - val_loss: 6.7967e-04 - val_mae: 0.0173 - 428ms/epoch - 4ms/step
# Epoch 181/10000
# 113/113 - 0s - loss: 6.8012e-04 - mae: 0.0174 - val_loss: 6.7953e-04 - val_mae: 0.0174 - 363ms/epoch - 3ms/step
# Epoch 182/10000
# 113/113 - 1s - loss: 6.8015e-04 - mae: 0.0175 - val_loss: 6.7999e-04 - val_mae: 0.0173 - 533ms/epoch - 5ms/step
# Epoch 183/10000
# 113/113 - 0s - loss: 6.7998e-04 - mae: 0.0174 - val_loss: 6.7949e-04 - val_mae: 0.0175 - 459ms/epoch - 4ms/step
# Epoch 184/10000
# 113/113 - 0s - loss: 6.8044e-04 - mae: 0.0175 - val_loss: 6.7899e-04 - val_mae: 0.0174 - 430ms/epoch - 4ms/step
# Epoch 185/10000
# 113/113 - 0s - loss: 6.8027e-04 - mae: 0.0174 - val_loss: 6.7876e-04 - val_mae: 0.0174 - 425ms/epoch - 4ms/step
# Epoch 186/10000
# 113/113 - 0s - loss: 6.8023e-04 - mae: 0.0175 - val_loss: 6.7948e-04 - val_mae: 0.0174 - 388ms/epoch - 3ms/step
# Epoch 187/10000
# 113/113 - 0s - loss: 6.8012e-04 - mae: 0.0174 - val_loss: 6.7865e-04 - val_mae: 0.0174 - 341ms/epoch - 3ms/step
# Epoch 188/10000
# 113/113 - 0s - loss: 6.8012e-04 - mae: 0.0175 - val_loss: 6.7923e-04 - val_mae: 0.0174 - 444ms/epoch - 4ms/step
# Epoch 189/10000
# 113/113 - 1s - loss: 6.8001e-04 - mae: 0.0174 - val_loss: 6.7885e-04 - val_mae: 0.0174 - 526ms/epoch - 5ms/step
# Epoch 190/10000
# 113/113 - 1s - loss: 6.8037e-04 - mae: 0.0175 - val_loss: 6.7881e-04 - val_mae: 0.0173 - 515ms/epoch - 5ms/step
# Epoch 191/10000
# 113/113 - 0s - loss: 6.8029e-04 - mae: 0.0175 - val_loss: 6.7853e-04 - val_mae: 0.0174 - 464ms/epoch - 4ms/step
# Epoch 192/10000
# 113/113 - 0s - loss: 6.8022e-04 - mae: 0.0175 - val_loss: 6.7869e-04 - val_mae: 0.0173 - 338ms/epoch - 3ms/step
# Epoch 193/10000
# 113/113 - 0s - loss: 6.8033e-04 - mae: 0.0175 - val_loss: 6.7931e-04 - val_mae: 0.0173 - 341ms/epoch - 3ms/step
# Epoch 194/10000
# 113/113 - 0s - loss: 6.8045e-04 - mae: 0.0175 - val_loss: 6.8011e-04 - val_mae: 0.0174 - 339ms/epoch - 3ms/step
# Epoch 195/10000
# 113/113 - 0s - loss: 6.8043e-04 - mae: 0.0175 - val_loss: 6.7879e-04 - val_mae: 0.0174 - 338ms/epoch - 3ms/step
# Epoch 196/10000
# 113/113 - 0s - loss: 6.8030e-04 - mae: 0.0175 - val_loss: 6.7856e-04 - val_mae: 0.0174 - 351ms/epoch - 3ms/step
# Epoch 197/10000
# 113/113 - 0s - loss: 6.8044e-04 - mae: 0.0175 - val_loss: 6.7967e-04 - val_mae: 0.0174 - 474ms/epoch - 4ms/step
# Epoch 198/10000
# 113/113 - 0s - loss: 6.8008e-04 - mae: 0.0174 - val_loss: 6.7927e-04 - val_mae: 0.0174 - 393ms/epoch - 3ms/step
# Epoch 199/10000
# 113/113 - 1s - loss: 6.8005e-04 - mae: 0.0174 - val_loss: 6.7889e-04 - val_mae: 0.0174 - 563ms/epoch - 5ms/step
# Epoch 200/10000
# 113/113 - 0s - loss: 6.7998e-04 - mae: 0.0175 - val_loss: 6.7976e-04 - val_mae: 0.0173 - 401ms/epoch - 4ms/step
# Epoch 201/10000
# 113/113 - 0s - loss: 6.7977e-04 - mae: 0.0174 - val_loss: 6.7867e-04 - val_mae: 0.0174 - 342ms/epoch - 3ms/step
# Epoch 202/10000
# 113/113 - 0s - loss: 6.8037e-04 - mae: 0.0174 - val_loss: 6.8053e-04 - val_mae: 0.0173 - 338ms/epoch - 3ms/step
# Epoch 203/10000
# 113/113 - 0s - loss: 6.8021e-04 - mae: 0.0175 - val_loss: 6.7945e-04 - val_mae: 0.0173 - 338ms/epoch - 3ms/step
# Epoch 204/10000
# 113/113 - 0s - loss: 6.8009e-04 - mae: 0.0175 - val_loss: 6.7922e-04 - val_mae: 0.0174 - 339ms/epoch - 3ms/step
# Epoch 205/10000
# 113/113 - 0s - loss: 6.8027e-04 - mae: 0.0174 - val_loss: 6.7900e-04 - val_mae: 0.0174 - 336ms/epoch - 3ms/step
# Epoch 206/10000
# 113/113 - 0s - loss: 6.8003e-04 - mae: 0.0175 - val_loss: 6.8003e-04 - val_mae: 0.0173 - 338ms/epoch - 3ms/step
# Epoch 207/10000
# 113/113 - 0s - loss: 6.8035e-04 - mae: 0.0174 - val_loss: 6.7859e-04 - val_mae: 0.0173 - 352ms/epoch - 3ms/step
# Epoch 208/10000
# 113/113 - 0s - loss: 6.8014e-04 - mae: 0.0175 - val_loss: 6.7919e-04 - val_mae: 0.0173 - 336ms/epoch - 3ms/step
# Epoch 209/10000
# 113/113 - 0s - loss: 6.8038e-04 - mae: 0.0175 - val_loss: 6.7995e-04 - val_mae: 0.0174 - 338ms/epoch - 3ms/step
# Epoch 210/10000
# 113/113 - 0s - loss: 6.8006e-04 - mae: 0.0174 - val_loss: 6.7924e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 211/10000
# 113/113 - 0s - loss: 6.8029e-04 - mae: 0.0175 - val_loss: 6.7905e-04 - val_mae: 0.0174 - 337ms/epoch - 3ms/step
# Epoch 212/10000
# 113/113 - 0s - loss: 6.8054e-04 - mae: 0.0175 - val_loss: 6.7879e-04 - val_mae: 0.0174 - 338ms/epoch - 3ms/step
# Epoch 213/10000
# 113/113 - 0s - loss: 6.8000e-04 - mae: 0.0174 - val_loss: 6.7870e-04 - val_mae: 0.0173 - 422ms/epoch - 4ms/step
# Epoch 214/10000
# 113/113 - 0s - loss: 6.8010e-04 - mae: 0.0175 - val_loss: 6.7855e-04 - val_mae: 0.0174 - 442ms/epoch - 4ms/step
# Epoch 215/10000
# 113/113 - 0s - loss: 6.8009e-04 - mae: 0.0174 - val_loss: 6.7902e-04 - val_mae: 0.0173 - 340ms/epoch - 3ms/step
# Epoch 216/10000
# Restoring model weights from the end of the best epoch: 191.
# 113/113 - 0s - loss: 6.8031e-04 - mae: 0.0175 - val_loss: 6.7922e-04 - val_mae: 0.0174 - 340ms/epoch - 3ms/step
# Epoch 216: early stopping
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/justinhudson/Documents/HW/ATS_780/Homework_2/DATA/MODELS/nontrainable_model/assets
# INFO:tensorflow:Assets written to: /Users/justinhudson/Documents/HW/ATS_780/Homework_2/DATA/MODELS/nontrainable_model/assets

# %%
fig, ax = plt.subplots(1,2, figsize = (10,4))

lw = 2

ax[0].plot(history.history["loss"],label = "Training",linewidth = lw)
ax[0].plot(history.history["val_loss"],label = "Validation",linewidth = lw)
ax[0].set_xlabel("Epoch",fontsize = 14)
ax[0].set_ylabel("Loss (MSE)",fontsize = 14)
ax[0].legend(loc = 'best',fontsize = 14)
ax[0].set_yscale('log')

ax[1].plot(history.history["mae"],label = "Training",linewidth = lw)
ax[1].plot(history.history["val_mae"],label = "Validation",linewidth = lw)
ax[1].set_xlabel("Epoch",fontsize = 14)
ax[1].set_ylabel("MAE",fontsize = 14)
#ax[1].legend(loc = 'best')
ax[1].set_yscale('log')

plt.suptitle(f'Loss Curve\n {x_train.shape[0]} Training Samples & {x_val.shape[0]} Validation Samples\n with Non-Trainable Filters',fontsize = 15)

plt.subplots_adjust(top = 0.8,wspace = 0.23)

os.chdir(figure_path)
plt.savefig(f'Nontrainable_Loss_Curve.png',dpi = 400,bbox_inches = 'tight')

plt.show()

# %%
filters,biases = model.layers[2].get_weights()
f_min,f_max = filters.min(), filters.max()
# filters = (filters - f_min) / (f_max - f_min)
n_filters, ix = N_FILTERS,1

output_filter,output_biases = model.layers[3].get_weights()
print(output_filter.shape)
print(filters.shape)

# cf2 = plt.imshow(filters[:,:,0,1], cmap = 'binary_r')
# plt.show()

fig,tf = plt.subplots(2,1,figsize = (6,4))
tf[0].set_title('U Channel Filters',fontsize = 15)
tf[1].set_title('V Channel Filters',fontsize = 15)
tf[0].set_frame_on(False)
tf[1].set_frame_on(False)
tf[0].axis('off')
tf[1].axis('off')

num_plot = 1
for i in range(2):
    for j in range(n_filters):
        ax = fig.add_subplot(2,n_filters,num_plot)
        if i == 0 and j == 0:
            pl = np.ones((3,3)) * f_max
            pl[0] = f_min
            kshow = ax.imshow(pl,cmap = 'bwr',vmin = -1,vmax = 1)
        ax.imshow(filters[:,:,i,j],cmap = 'bwr',vmin = -1,vmax = 1)
        # ax.set_xticks([0,1,2],['-1','0','+1'])
        # ax.set_yticks([0,1,2],['+1','0','-1'])
        ax.set_xticks([])
        ax.set_yticks([])
        num_plot += 1
# cf0 = ax[0,0].imshow(filters[:,:,0,0], cmap = 'binary_r')

# cf1 = ax[0,1].imshow(filters[:,:,1,0], cmap = 'binary_r')




# cf3 = ax[1,1].imshow(filters[:,:,1,1], cmap = 'binary_r')

plt.subplots_adjust(bottom = 0.2, hspace = 0.6,wspace = 0.1,top = 0.8)

cax = plt.axes([0.05,0.1,0.9,0.06])
cb = plt.colorbar(kshow,cax = cax, orientation = 'horizontal')
cb.set_label(label = 'Pixel Weight',fontsize = 12)
cb.ax.tick_params(labelsize = 10)
cb.set_ticks([-1,-0.75,-0.5,-0.25,0,0.25,0.5,0.75,1.0])

fig.suptitle("Non-Trainable Model Hidden Layer Kernels", fontsize = 16)

plt.savefig(f"Nontrainable_filters.png",dpi = 400,bbox_inches = 'tight')
plt.show()
# Out:
# (3, 3, 2, 1)
# (3, 3, 2, 2)
